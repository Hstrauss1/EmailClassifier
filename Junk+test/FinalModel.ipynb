# %%
import os
import re
import argparse
from email import policy
from email.parser import BytesParser

import nltk
from nltk.corpus import stopwords

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, confusion_matrix

# Ensure NLTK stopwords are downloaded
nltk.download('stopwords', quiet=True)
STOPWORDS = set(stopwords.words('english'))

import re

from nltk.stem import PorterStemmer, WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
STOPWORDS = set(stopwords.words('english'))
stemmer = PorterStemmer()

def clean_text(text: str) -> str:
    text = text.lower()
    text = re.sub(r'https?://\S+|www\.\S+', '', text)  # strip URLs
    text = re.sub(r'[^a-z0-9\s]', ' ', text)           # strip punctuation
    text = re.sub(r'\s+', ' ', text).strip()           # collapse whitespace

    tokens = []
    for word in text.split():
        if word in STOPWORDS:
            continue
        stemmed = stemmer.stem(word)
        lemma = lemmatizer.lemmatize(stemmed)
        tokens.append(lemma)

    return ' '.join(tokens)
print("DONE")
# Out:
# DONE

# %%
def load_emails(maildir: str):
    texts, labels = [], []
    cnt = 0
    for user in os.listdir(maildir):
        user_dir = os.path.join(maildir, user)
        if not os.path.isdir(user_dir):
            continue

        # only look at the “sent_items” folder
        folder_dir = os.path.join(user_dir, "sent_items")
        print(f"Processing user #{cnt}: {user}")
        cnt += 1
        if not os.path.isdir(folder_dir):
            continue

        for fname in os.listdir(folder_dir):
            path = os.path.join(folder_dir, fname)
            try:
                with open(path, 'rb') as f:
                    msg = BytesParser(policy=policy.default).parse(f)
                body = msg.get_body(preferencelist=('plain',))
                if body is None:
                    continue
                raw = body.get_content()
                text = clean_text(raw)
                if text:  # already lemmatized and stopwords‐free
                    texts.append(text)
                    labels.append(user)
            except Exception:
                continue

    return texts, labels

print("done")
# Out:
# done

# %%
import os
import sys
import statistics

def count_sent_messages(maildir):
    counts = []
    for user in os.listdir(maildir):
        sent_dir = os.path.join(maildir, user, "sent_items")
        if os.path.isdir(sent_dir):
            n = sum(
                1
                for fname in os.listdir(sent_dir)
                if os.path.isfile(os.path.join(sent_dir, fname))
            )
            counts.append(n)
    return counts

def getAve(maildir):
    counts = count_sent_messages(maildir)
    if not counts:
        print("No users or no sent_items folders found.")
        return

    avg    = statistics.mean(counts)
    med    = statistics.median(counts)
    stddev = statistics.stdev(counts)

    print(f"Average # of sent messages per user: {avg:.2f}")
    print(f"Median  # of sent messages per user: {med}")
    print(f"Std Dev # of sent messages per user: {stddev:.2f}")
getAve("/WAVE/projects/CSEN-140-Sp25/HHJ140Proj/Sent_Items_only")
# Out:
# Average # of sent messages per user: 278.82
# Median  # of sent messages per user: 144.5
# Std Dev # of sent messages per user: 318.26

# %%
DATA_DIR = "/WAVE/projects/CSEN-140-Sp25/HHJ140Proj/Sent_Items_only"     # path to Enron stuf
TEST_SIZE = 0.3 #preprocess work
RANDOM_STATE = 36

print("Loading and cleaning emails…")
texts, labels = load_emails(DATA_DIR)
print(f"→ {len(texts)} messages from {len(set(labels))} authors")
print(len(texts))
# Out:
# Loading and cleaning emails…
# Processing user #0: neal-s
# Processing user #1: griffith-j
# Processing user #2: zipper-a
# Processing user #3: baughman-d
# Processing user #4: kuykendall-t
# Processing user #5: saibi-e
# Processing user #6: quenet-j
# Processing user #7: buy-r
# Processing user #8: heard-m
# Processing user #9: presto-k
# Processing user #10: stepenovitch-j
# Processing user #11: pimenov-v
# Processing user #12: hayslett-r
# Processing user #13: parks-j
# Processing user #14: holst-k
# Processing user #15: campbell-l
# Processing user #16: crandell-s
# Processing user #17: bass-e
# Processing user #18: geaccone-t
# Processing user #19: carson-m
# Processing user #20: quigley-d
# Processing user #21: wolfe-j
# Processing user #22: gay-r
# Processing user #23: hendrickson-s
# Processing user #24: causholli-m
# Processing user #25: mann-k
# Processing user #26: shively-h
# Processing user #27: love-p
# Processing user #28: scott-s
# Processing user #29: martin-t
# Processing user #30: mims-thurston-p
# Processing user #31: schwieger-j
# Processing user #32: jones-t
# Processing user #33: giron-d
# Processing user #34: williams-w3
# Processing user #35: motley-m
# Processing user #36: gilbertsmith-d
# Processing user #37: brawner-s
# Processing user #38: allen-p
# Processing user #39: davis-d
# Processing user #40: lenhart-m
# Processing user #41: tycholiz-b
# Processing user #42: fischer-m
# Processing user #43: hyatt-k
# Processing user #44: panus-s
# Processing user #45: lucci-p
# Processing user #46: haedicke-m
# Processing user #47: slinger-r
# Processing user #48: taylor-m
# Processing user #49: germany-c
# Processing user #50: swerzbin-m
# Processing user #51: kitchen-l
# Processing user #52: shackleton-s
# Processing user #53: meyers-a
# Processing user #54: nemec-g
# Processing user #55: ring-a
# Processing user #56: smith-m
# Processing user #57: staab-t
# Processing user #58: solberg-g
# Processing user #59: skilling-j
# Processing user #60: arnold-j
# Processing user #61: blair-l
# Processing user #62: rapp-b
# Processing user #63: donoho-l
# Processing user #64: delainey-d
# Processing user #65: steffes-j
# Processing user #66: sanchez-m
# Processing user #67: badeer-r
# Processing user #68: lokey-t
# Processing user #69: beck-s
# Processing user #70: dasovich-j
# Processing user #71: grigsby-m
# Processing user #72: storey-g
# Processing user #73: ring-r
# Processing user #74: hernandez-j
# Processing user #75: semperger-c
# Processing user #76: dorland-c
# Processing user #77: bailey-s
# Processing user #78: perlingiere-d
# Processing user #79: cuilla-m
# Processing user #80: platter-p
# Processing user #81: arora-h
# Processing user #82: salisbury-h
# Processing user #83: phanis-s
# Processing user #84: ward-k
# Processing user #85: mckay-b
# Processing user #86: kaminski-v
# Processing user #87: townsend-j
# Processing user #88: schoolcraft-d
# Processing user #89: ermis-f
# Processing user #90: corman-s
# Processing user #91: richey-c
# Processing user #92: sanders-r
# Processing user #93: sager-e
# Processing user #94: mccarty-d
# Processing user #95: kean-s
# Processing user #96: scholtes-d
# Processing user #97: sturm-f
# Processing user #98: gang-l
# Processing user #99: lokay-m
# Processing user #100: rogers-b
# Processing user #101: lavorato-j
# Processing user #102: whalley-g
# Processing user #103: king-j
# Processing user #104: shankman-j
# Processing user #105: weldon-c
# Processing user #106: dean-c
# Processing user #107: tholt-j
# Processing user #108: cash-m
# Processing user #109: hodge-j
# Processing user #110: zufferli-j
# Processing user #111: watson-k
# Processing user #112: forney-j
# Processing user #113: mclaughlin-e
# Processing user #114: benson-r
# Processing user #115: reitmeyer-j
# Processing user #116: whitt-m
# Processing user #117: mckay-j
# Processing user #118: donohoe-t
# Processing user #119: ybarbo-p
# Processing user #120: may-l
# Processing user #121: farmer-d
# Processing user #122: derrick-j
# Processing user #123: williams-j
# Processing user #124: keavey-p
# Processing user #125: lewis-a
# Processing user #126: keiser-k
# Processing user #127: thomas-p
# Processing user #128: white-s
# Processing user #129: shapiro-r
# Processing user #130: ruscitti-k
# Processing user #131: maggi-m
# Processing user #132: lay-k
# Processing user #133: pereira-s
# Processing user #134: horton-s
# Processing user #135: mcconnell-m
# → 37664 messages from 136 authors
# 37664

# %%
print("Vectorizing with TF–IDF…")
vect = TfidfVectorizer(max_features=20_000)
X = vect.fit_transform(texts)
y = labels
# Out:
# Vectorizing with TF–IDF…

# %%
from collections import Counter

counts = Counter(labels)

keep = {lbl for lbl, cnt in counts.items() if cnt >= 2}

texts_filt = [t for t, l in zip(texts, labels) if l in keep]
labels_filt = [l for l in labels if l in keep]

X = vect.transform(texts_filt)   
y = labels_filt

X_train, X_test, y_train, y_test = train_test_split( #split and train
    X, y,
    test_size=TEST_SIZE,
    stratify=y,
    random_state=RANDOM_STATE
)
print(f"→ Training on {X_train.shape[0]} docs; testing on {X_test.shape[0]}")
# Out:
# → Training on 26364 docs; testing on 11299

# %%
from sklearn.svm import LinearSVC

models = {
    "Linear SVC": LinearSVC(C=1.0, max_iter=10000, dual=False)
}

for name, model in models.items():
    print(f"\n{name}")
    model.fit(X_train, y_train)
    print("fitted")
    preds = model.predict(X_test)
    print(classification_report(y_test, preds))
    #print("Confusion matrix:")
    #print(confusion_matrix(y_test, preds))
# Out:
# Linear SVC
# fitted
#                  precision    recall  f1-score   support
#
#         allen-p       0.79      0.75      0.77       103
#        arnold-j       0.72      0.71      0.72       216
#         arora-h       0.79      0.55      0.65        20
#        badeer-r       0.50      0.50      0.50         2
#        bailey-s       1.00      1.00      1.00         4
#          bass-e       0.76      0.70      0.73        73
#      baughman-d       0.75      0.64      0.69        28
#          beck-s       0.87      0.90      0.89       145
#        benson-r       0.50      0.40      0.44         5
#         blair-l       0.90      0.95      0.93       278
#       brawner-s       0.71      0.68      0.70        22
#           buy-r       0.86      0.84      0.85       117
#      campbell-l       0.82      0.91      0.86        34
#        carson-m       0.89      0.91      0.90        34
#          cash-m       0.88      0.88      0.88       164
#     causholli-m       0.96      1.00      0.98        67
#        corman-s       0.75      0.71      0.73       188
#      crandell-s       0.77      0.77      0.77        44
#        cuilla-m       0.68      0.63      0.66        41
#      dasovich-j       0.83      0.90      0.86       430
#         davis-d       0.92      0.79      0.85        14
#          dean-c       0.38      0.30      0.33        10
#      delainey-d       0.92      0.61      0.73        18
#       derrick-j       0.86      0.93      0.89       175
#        donoho-l       0.71      0.71      0.71        65
#       donohoe-t       0.83      0.56      0.67         9
#       dorland-c       0.76      0.86      0.81       176
#         ermis-f       0.00      0.00      0.00         5
#        farmer-d       0.85      0.75      0.80        77
#       fischer-m       0.94      0.79      0.86        19
#        forney-j       0.92      0.95      0.94       128
#          gang-l       1.00      0.93      0.96        27
#           gay-r       0.00      0.00      0.00         3
#      geaccone-t       0.77      0.71      0.74       109
#       germany-c       0.80      0.84      0.82       401
#  gilbertsmith-d       0.50      0.50      0.50         4
#         giron-d       0.77      0.81      0.79        89
#      griffith-j       0.83      0.83      0.83        12
#       grigsby-m       0.68      0.72      0.70        87
#      haedicke-m       0.82      0.66      0.73        35
#      hayslett-r       0.61      0.82      0.70       159
#         heard-m       0.87      0.92      0.89       235
#   hendrickson-s       0.69      0.50      0.58        18
#     hernandez-j       0.85      0.58      0.69        19
#         hodge-j       0.78      0.48      0.60        29
#         holst-k       0.71      0.45      0.56        11
#        horton-s       0.76      0.76      0.76        46
#         hyatt-k       0.79      0.81      0.80        96
#         jones-t       0.86      0.77      0.81        94
#      kaminski-v       0.92      0.95      0.93       497
#          kean-s       0.72      0.69      0.70       137
#        keavey-p       0.73      0.89      0.80         9
#        keiser-k       0.88      0.84      0.86       109
#          king-j       1.00      0.25      0.40         4
#       kitchen-l       0.75      0.81      0.78       339
#    kuykendall-t       0.86      0.66      0.75        38
#      lavorato-j       0.60      0.61      0.61       201
#           lay-k       1.00      0.25      0.40         4
#       lenhart-m       0.74      0.81      0.77       230
#         lewis-a       0.67      0.29      0.40         7
#         lokay-m       0.76      0.62      0.68        45
#         lokey-t       0.89      0.69      0.78        36
#          love-p       0.86      0.83      0.84       178
#         lucci-p       0.74      0.70      0.72        70
#         maggi-m       0.76      0.74      0.75        35
#          mann-k       0.89      0.71      0.79        79
#        martin-t       0.80      0.78      0.79        68
#           may-l       0.67      0.62      0.64        13
#       mccarty-d       0.78      0.62      0.69        52
#     mcconnell-m       0.67      0.67      0.67        33
#         mckay-b       0.90      0.69      0.78        13
#         mckay-j       0.84      0.76      0.80        89
#    mclaughlin-e       0.83      0.78      0.81        32
#        meyers-a       0.00      0.00      0.00         3
# mims-thurston-p       0.81      0.67      0.73        69
#        motley-m       1.00      0.50      0.67         4
#          neal-s       0.72      0.73      0.73        67
#         nemec-g       0.81      0.87      0.84       179
#         panus-s       0.83      0.62      0.71         8
#         parks-j       0.80      0.78      0.79       166
#       pereira-s       0.79      0.68      0.73        22
#   perlingiere-d       0.95      0.97      0.96       174
#        phanis-s       0.00      0.00      0.00         1
#       pimenov-v       0.67      0.57      0.62        21
#       platter-p       0.73      0.59      0.66        32
#        presto-k       0.76      0.75      0.75       287
#        quenet-j       1.00      0.50      0.67         2
#       quigley-d       0.84      0.83      0.84       150
#          rapp-b       0.86      0.61      0.72        31
#     reitmeyer-j       0.71      0.62      0.67        16
#        richey-c       0.86      0.86      0.86        74
#          ring-a       0.50      0.38      0.43         8
#          ring-r       0.91      0.67      0.77        15
#        rogers-b       0.89      0.93      0.91        27
#      ruscitti-k       0.79      0.68      0.73        22
#         sager-e       0.90      0.84      0.87       125
#         saibi-e       1.00      0.50      0.67        10
#     salisbury-h       0.73      0.54      0.62        41
#       sanchez-m       0.72      0.62      0.67        29
#       sanders-r       0.89      0.80      0.84       121
#      scholtes-d       0.72      0.49      0.58        37
#   schoolcraft-d       0.83      0.85      0.84       144
#     schwieger-j       0.76      0.87      0.81        45
#         scott-s       0.74      0.85      0.79       201
#     semperger-c       0.69      0.67      0.68        79
#    shackleton-s       0.92      0.89      0.90       190
#      shankman-j       0.84      0.89      0.86        18
#       shively-h       0.46      0.34      0.39        38
#      skilling-j       0.93      0.81      0.87        16
#       slinger-r       0.67      0.43      0.52        14
#         smith-m       0.90      0.87      0.88        70
#       solberg-g       0.50      0.50      0.50        16
#         staab-t       0.84      0.93      0.89        29
#       steffes-j       0.83      0.91      0.87       414
#  stepenovitch-j       0.88      0.96      0.92        23
#        storey-g       0.81      0.63      0.71        41
#         sturm-f       0.83      0.78      0.80        49
#      swerzbin-m       0.73      0.52      0.61        21
#        taylor-m       0.79      0.73      0.76       164
#         tholt-j       0.90      0.72      0.80        74
#        thomas-p       0.84      0.67      0.75        46
#      townsend-j       0.33      0.20      0.25         5
#      tycholiz-b       0.79      0.80      0.80       106
#          ward-k       0.79      0.81      0.80       203
#        watson-k       0.80      0.83      0.82       290
#        weldon-c       0.80      0.80      0.80        54
#       whalley-g       0.46      0.30      0.36        20
#         white-s       0.87      0.93      0.90       134
#         whitt-m       0.72      0.64      0.67        91
#      williams-j       0.78      0.66      0.71        38
#     williams-w3       0.78      0.86      0.82       155
#         wolfe-j       0.76      0.89      0.82        28
#        ybarbo-p       0.62      0.69      0.65        35
#        zipper-a       0.42      0.52      0.47       103
#      zufferli-j       0.77      0.66      0.71       101
#
#        accuracy                           0.80     11299
#       macro avg       0.76      0.69      0.71     11299
#    weighted avg       0.80      0.80      0.80     11299
# /WAVE/users2/unix/hstrauss/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /WAVE/users2/unix/hstrauss/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /WAVE/users2/unix/hstrauss/.local/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
# Linear SVM is the best. Preform For the full data set.
